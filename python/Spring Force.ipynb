# %%
import numpy as np
import matplotlib.pyplot as plt
import utils
plt.style.use('prl')

# %%
x = np.linspace(-10,10,1000)

# %%
plt.plot(x,x**2)
plt.plot(x,x**3)

# %%
plt.plot(x,-x-x**3)
plt.plot(x,-x-0.5*x**3)
plt.plot(x,-x-0.1*x**3)
plt.title(r"Force from $\beta$")
plt.xlim(-1,1)
plt.ylim(-1,1)
# Out:
# (-1.0, 1.0)

# %%
plt.plot(x,-x-x**2)
plt.plot(x,-x-0.5*x**2)
plt.plot(x,-x-0.1*x**2)

plt.title(r"Force from $\alpha$")
plt.xlim(-1,1)
plt.ylim(-1,1)
# Out:
# (-1.0, 1.0)
