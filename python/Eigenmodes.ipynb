# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import utils
from fput_test import hamiltonian
plt.style.use('prl')

# %%
hamiltonian??

# %%
N=14
ke=1
ko=1

# %%
H = utils.linear_operator(N, k1=ko, k2=ke)
omega, evecs = utils.efreq(H)

# %%
evecs.shape
# Out:
# (14, 14)

# %%
plt.imshow(evecs)

# %%
plt.plot(evecs[:,0])

# %%
omega
# Out:
# array([0.20905693, 0.41582338, 0.61803399, 0.81347329, 1.        ,
#        1.1755705 , 1.33826121, 1.48628965, 1.61803399, 1.73205081,
#        1.82709092, 1.90211303, 1.9562952 , 1.98904379])

# %%
plt.imshow(H)

# %%
df = h5py.File("data/run_4_output.h5", "r")
t = df['scales/t'][:]
e1 = df['energies/e_1'][:]
e1m = df['energies/e_1_emode'][:]
e2 = df['energies/e_2'][:]
e2m = df['energies/e_2_emode'][:]
df.close()

# %%
fac = e1[0]/e1m[0]
print(fac)
# Out:
# 56.25

# %%
14/2
# Out:
# 7.0

# %%
plt.plot(t,e1-fac*e1m)
#plt.plot(t,fac*e1m,'x')
